# %% [markdown]
# ### Question-2 Part-3 - Pointmass-Hard

# %%
import utils as u
import numpy as np

# %%
cql_a0_02_shifted = "../../data/p2-p3/hw5_expl_q2_alpha0_02_PointmassHard-v0_*"
cql_a0_5_shifted = "../../data/p2-p3/hw5_expl_q2_alpha0_5_PointmassHard-v0_*"
cql_a1_0_shifted = "../../data/p2-p3/hw5_expl_q2_alpha1_PointmassHard-v0_*"

# %%
u.print_seeds(cql_a1_0_shifted)
# Out:
# ../../data/p2-p3/hw5_expl_q2_alpha1_PointmassHard-v0_03-03-2023_09-58-53
# ../../data/p2-p3/hw5_expl_q2_alpha1_PointmassHard-v0_03-03-2023_10-00-24
# ../../data/p2-p3/hw5_expl_q2_alpha1_PointmassHard-v0_03-03-2023_10-05-45
# ../../data/p2-p3/hw5_expl_q2_alpha1_PointmassHard-v0_03-03-2023_10-08-33

# %% [markdown]
# ## Eval Return Plot

# %%
arr_cql_a0_02_shifted = u.average_metrics(cql_a0_02_shifted, 2)
arr_cql_a0_5_shifted = u.average_metrics(cql_a0_5_shifted, 2)
arr_cql_a1_0_shifted = u.average_metrics(cql_a1_0_shifted, 2)

u.plot_arrays("Evaluation Return (CQL Alpha)",[arr_cql_a0_02_shifted, arr_cql_a0_5_shifted, arr_cql_a1_0_shifted],
              ['CQL 0.02','CQL 0.5', 'CQL 1.0'])
