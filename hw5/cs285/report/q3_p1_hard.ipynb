# %% [markdown]
# # Question-3 Part-1 - Pointmass-Hard

# %%
import utils as u
import numpy as np

# %% [markdown]
# Commands:
# - python -m cs285.scripts.run_hw5_expl --env_name PointmassHard-v0 --unsupervised_exploration --exp_name q1_env3_random --seed 0
# - python -m cs285.scripts.run_hw5_expl --env_name PointmassHard-v0 --use_rnd --unsupervised_exploration --exp_name q1_env3_rnd --seed 0

# %%
qn_online = ""

dqn_20k = "../../data/q3/hw5_expl_q3_hard_dqn_PointmassHard-v0_*"
cql_20k = "../../data/q3/hw5_expl_q3_hard_cql_PointmassHard-v0_*"

dqn_10k = "../../data/q3/hw5_expl_q3_hard_dqn_10K_PointmassHard-v0_*"
cql_10k = "../../data/q3/hw5_expl_q3_hard_cql_10K_PointmassHard-v0_*"

# %%
u.print_seeds(cql_10k)
# Out:
# ../../data/q3/hw5_expl_q3_hard_cql_10K_PointmassHard-v0_26-02-2023_09-38-01
# ../../data/q3/hw5_expl_q3_hard_cql_10K_PointmassHard-v0_26-02-2023_11-42-42
# ../../data/q3/hw5_expl_q3_hard_cql_10K_PointmassHard-v0_26-02-2023_09-32-25
# ../../data/q3/hw5_expl_q3_hard_cql_10K_PointmassHard-v0_26-02-2023_11-50-56

# %% [markdown]
# ## Training Return Plot

# %%
arr_dqn_20k = u.average_metrics(dqn_20k, 1)
arr_cql_20k = u.average_metrics(cql_20k, 1)
arr_dqn_10k = u.average_metrics(dqn_10k, 1)
arr_cql_10k = u.average_metrics(cql_10k, 1)

arr_dqn_20k[1:2]=None
arr_dqn_10k[1:2]=None
arr_cql_20k[1:2]=None
arr_cql_10k[1:2]=None

u.plot_arrays("Training Return",[arr_dqn_20k, arr_cql_20k,arr_dqn_10k,arr_cql_10k],['DQN','CQL','DQN 10K','CQL 10K'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
arr_dqn_20k = u.average_metrics(dqn_20k, 2)
arr_cql_20k = u.average_metrics(cql_20k, 2)
arr_dqn_10k = u.average_metrics(dqn_10k, 2)
arr_cql_10k = u.average_metrics(cql_10k, 2)

u.plot_arrays("Evaluation Return",[arr_dqn_20k, arr_cql_20k,arr_dqn_10k,arr_cql_10k],['DQN','CQL','DQN 10K','CQL 10K'])

# %% [markdown]
# ## Mixed (Extrinsic only) Rewards (0-10K)

# %%
arr_rnd = u.average_metrics(seed_prefix_rnd, 3, shift=0, clip=10)
u.plot_arrays("Mixed Rewards (0-10K)",[arr_rnd],['RND'])

# %% [markdown]
# ## Environment Rewards 10K-50K

# %%
arr_rand = u.average_metrics(seed_prefix_rand, 4, shift=11)
arr_rnd = u.average_metrics(seed_prefix_rnd, 4, shift=11)
u.plot_arrays("Env Rewards 10K+(0-40K)",[arr_rand, arr_rnd],['Random','RND'])

# %% [markdown]
# ## Random Exploitation Values

# %%
u.show_graphs_seed_steps(seed_prefix_rand, "exploitation_value", [10_000, 50_000])

# %% [markdown]
# ## RND Exploitation Values

# %%
u.show_graphs_seed_steps(seed_prefix_rnd, "exploitation_value", [10_000, 50_000])

# %% [markdown]
# ## Random Exploration Values

# %%
u.show_graphs_seed_steps(seed_prefix_rand, "exploration_value", [1_000, 10_000])

# %% [markdown]
# ## Rnd Exploration Values

# %%
u.show_graphs_seed_steps(seed_prefix_rnd, "exploration_value", [1_000, 10_000])

# %% [markdown]
# ## Random State Density

# %%
u.show_graphs_seed_steps(seed_prefix_rand, "state_density", [10_000, 50_000])

# %% [markdown]
# ## RND State Density

# %%
u.show_graphs_seed_steps(seed_prefix_rnd, "state_density", [10_000, 50_000])

# %%
u.show_graphs_seed_steps(seed_prefix_rnd, "rnd_value", [3_000, 10_000])

# %%
import glob
glob.glob(seed_prefix_rnd + f"/0/expl")
# Out:
# ['../../data/q1-p1/hw5_expl_q1_env3_rnd_PointmassHard-v0_21-02-2023_12-07-02/0/expl',
#  '../../data/q1-p1/hw5_expl_q1_env3_rnd_PointmassHard-v0_21-02-2023_13-44-42/0/expl',
#  '../../data/q1-p1/hw5_expl_q1_env3_rnd_PointmassHard-v0_21-02-2023_12-05-26/0/expl',
#  '../../data/q1-p1/hw5_expl_q1_env3_rnd_PointmassHard-v0_21-02-2023_13-49-04/0/expl']

# %%
seed_prefix_rnd + f"/*/0/expl"
# Out:
# '../../data/q1-p1/hw5_expl_q1_env3_rnd_PointmassHard-v0_*/*/0/expl'

# %%
u.plot_merged_traj_seeds(seed_prefix_rand,0)

# %%
u.plot_merged_traj_seeds(seed_prefix_rnd,0)
