# %% [markdown]
# # Question-3 Part-1 - Pointmass-Medium

# %%
import utils as u
import numpy as np

# %%
dqn_20k = "../../data/p3-offline/hw5_expl_q3_medium_dqn_PointmassMedium-v0_*"
cql_20k = "../../data/p3-offline/hw5_expl_q3_medium_cql_PointmassMedium-v0_*"

dqn_10k = "../../data/p3-offline/hw5_expl_q3_medium_dqn_10K_PointmassMedium-v0_*"
cql_10k = "../../data/p3-offline/hw5_expl_q3_medium_cql_10K_PointmassMedium-v0_*"

dqn_20K_offline_unsuper = "../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_*"
cql_20K_offline_unsuper = "../../data/p2-p2/hw5_expl_q2_cql_numsteps_20000_PointmassMedium-v0_*"

# %%
u.print_seeds(dqn_20K_offline_unsuper)
# Out:
# ../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_02-03-2023_23-59-29
# ../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_02-03-2023_23-59-44
# ../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_03-03-2023_00-05-53
# ../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_03-03-2023_00-06-31

# %% [markdown]
# ## Evaluation Return Plot

# %%
arr_dqn_20k = u.average_metrics(dqn_20k, 2)
arr_cql_20k = u.average_metrics(cql_20k, 2)
arr_dqn_10k = u.average_metrics(dqn_10k, 2)
arr_cql_10k = u.average_metrics(cql_10k, 2)

arr_dqn_20K_offline_unsuper = u.average_metrics(dqn_20K_offline_unsuper, 2)
arr_cql_20K_offline_unsuper = u.average_metrics(cql_20K_offline_unsuper, 2)

u.plot_arrays("Evaluation Return",[arr_dqn_20k, arr_cql_20k,arr_dqn_10k,arr_cql_10k, arr_dqn_20K_offline_unsuper, arr_cql_20K_offline_unsuper],['DQN 20K','CQL 20K','DQN 10K','CQL 10K', 'DQN 20K Off-Unsup','CQL 20K Off-Unsup'])
