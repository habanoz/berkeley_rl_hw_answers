# %% [markdown]
# # Question-4 Part-1 - Pointmass-Easy - Unsupervised

# %%
import utils as u
import numpy as np

# %%
lam0_1 = "../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam0_1"
lam1 = "../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam1_"
lam2 = "../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam2_"
lam10 = "../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam10_"
lam20 = "../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam20_"
lam50 = "../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam50_"

# %%
u.print_seeds(lam50)
# Out:
# ../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam50_PointmassEasy-v0_08-03-2023_02-01-31
# ../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam50_PointmassEasy-v0_08-03-2023_02-03-41
# ../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam50_PointmassEasy-v0_08-03-2023_16-29-24
# ../../data/awac/hw5_expl_q4_awac_easy_unsupervised_lam50_PointmassEasy-v0_08-03-2023_16-38-16

# %% [markdown]
# ## Training Return Plot

# %%
a_lam0_1 = u.average_metrics(lam0_1, 1)
a_lam1 = u.average_metrics(lam1, 1)
a_lam2 = u.average_metrics(lam2, 1)
a_lam10 = u.average_metrics(lam10, 1)
a_lam20 = u.average_metrics(lam20, 1)
a_lam50 = u.average_metrics(lam50, 1)

a_lam0_1[0] = None
a_lam1[0] = None
a_lam2[0] = None
a_lam10[0] = None
a_lam20[0] = None
a_lam50[0] = None

u.plot_arrays("Training Return",[a_lam0_1, a_lam1, a_lam2, a_lam10, a_lam20, a_lam50],
              ['lambda 0.1','lamda 1', 'lamda 2', 'lamda 10', 'lamda 20', 'lamda 50'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
a_lam0_1 = u.average_metrics(lam0_1, 2)
a_lam1 = u.average_metrics(lam1, 2)
a_lam2 = u.average_metrics(lam2, 2)
a_lam10 = u.average_metrics(lam10, 2)
a_lam20 = u.average_metrics(lam20, 2)
a_lam50 = u.average_metrics(lam50, 2)


u.plot_arrays("Evaluation Return",[a_lam0_1, a_lam1, a_lam2, a_lam10, a_lam20, a_lam50],
              ['lambda 0.1','lamda 1', 'lamda 2', 'lamda 10', 'lamda 20', 'lamda 50'])
