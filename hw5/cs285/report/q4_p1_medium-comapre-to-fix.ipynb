# %% [markdown]
# # Question-4 Part-1 - Pointmass-Medium - Unsupervised -  Compare To Fix

# %%
import utils as u
import numpy as np

# %%
lam0_1 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam0_1"
lam1 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam1_"
lam2 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam2_"
lam10 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam10_"
lam20 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam20_"
lam50 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam50_"

cql_a0_02_shifted = "../../data/p2-p3/hw5_expl_q2_alpha0_02_PointmassMedium-v0_*"
dqn_online_shifted = "../../data/q2-p1/hw5_expl_q1_env2_rnd_shifted_PointmassMedium-v0_*"
dqn_off_20000_shifted = "../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_*"

awac_hw = "/home/melek/PycharmProjects/ReinforcementLearningHW/hw5/data/awac/hw5_expl_q4_awac_medium_unsupervised_lam10_PointmassMedium-v0_*"
awac_j = "/home/melek/PycharmProjects/homework_fall2022_jesper/hw5/data/awac22/hw5_expl_q4_awac_medium_unsupervised_lam10_PointmassMedium-v0_*"

# %%
u.print_seeds(awac_hw)
# Out:
# /home/melek/PycharmProjects/ReinforcementLearningHW/hw5/data/awac/hw5_expl_q4_awac_medium_unsupervised_lam10_PointmassMedium-v0_09-03-2023_12-41-45
# /home/melek/PycharmProjects/ReinforcementLearningHW/hw5/data/awac/hw5_expl_q4_awac_medium_unsupervised_lam10_PointmassMedium-v0_09-03-2023_12-41-48

# %% [markdown]
# ## Training Return Plot

# %%
a_lam0_1 = u.average_metrics(lam0_1, 1)
a_lam1 = u.average_metrics(lam1, 1)
a_lam2 = u.average_metrics(lam2, 1)
a_lam10 = u.average_metrics(lam10, 1)
a_lam20 = u.average_metrics(lam20, 1)
a_lam50 = u.average_metrics(lam50, 1)

a_lam0_1[0] = None
a_lam1[0] = None
a_lam2[0] = None
a_lam10[0] = None
a_lam20[0] = None
a_lam50[0] = None

u.plot_arrays("Training Return",[a_lam0_1, a_lam1, a_lam2, a_lam10, a_lam20, a_lam50],
              ['lambda 0.1','lamda 1', 'lamda 2', 'lamda 10', 'lamda 20', 'lamda 50'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
a_lam0_1 = u.average_metrics(lam0_1, 2)
a_lam1 = u.average_metrics(lam1, 2)
a_lam2 = u.average_metrics(lam2, 2)
a_lam10 = u.average_metrics(lam10, 2)
a_lam20 = u.average_metrics(lam20, 2)
a_lam50 = u.average_metrics(lam50, 2)


u.plot_arrays("Evaluation Return",[a_lam0_1, a_lam1, a_lam2, a_lam10, a_lam20, a_lam50],
              ['lambda 0.1','lamda 1', 'lamda 2', 'lamda 10', 'lamda 20', 'lamda 50'])

# %% [markdown]
# ## Comparing to Other Algorithms

# %%
a_lam20 = u.average_metrics(lam20, 2)
a_lam10 = u.average_metrics(lam10, 2)
a_cql_a0_02_shifted = u.average_metrics(cql_a0_02_shifted, 2)
a_dqn_online_shifted = u.average_metrics(dqn_online_shifted, 2)
a_dqn_off_20000_shifted = u.average_metrics(dqn_off_20000_shifted, 2)
a_awac_j = u.average_metrics(awac_j, 2)
a_awac_hw = u.average_metrics(awac_hw, 2)

u.plot_arrays("Evaluation Return",[a_lam20,a_lam10, a_cql_a0_02_shifted, a_dqn_online_shifted, a_dqn_off_20000_shifted, a_awac_j, a_awac_hw],
              ['AWAC - lamda 20 - expl20K','AWAC - lamda 10 - expl20K','CQL Offline - alpha 0.02 - expl20K','DQN - expl10K','DQN Offline - expl20K', 'awac_j','a_awac_hw'])
