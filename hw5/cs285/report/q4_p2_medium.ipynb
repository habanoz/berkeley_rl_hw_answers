# %% [markdown]
# ## Question-4 Part-2 - Pointmass-Medium - Supervised

# %%
import utils as u
import numpy as np

# %%
lam0_1 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam0_1"
lam1 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam1_"
lam2 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam2_"
lam10 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam10_"
lam20 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam20_"
lam50 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam50_"

dqn_online_shifted = "../../data/q2-p1/hw5_expl_q1_env2_rnd_shifted_PointmassMedium-v0_*"
dqn_off_20000_shifted = "../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_*"

dqn_20k = "../../data/p3/hw5_expl_q3_medium_dqn_PointmassMedium-v0_*"
cql_20k = "../../data/p3/hw5_expl_q3_medium_cql_PointmassMedium-v0_*"

# %%
u.print_seeds(lam2)
# Out:
# ../../data/awac/hw5_expl_q4_awac_medium_supervised_lam2_PointmassMedium-v0_08-03-2023_11-02-17
# ../../data/awac/hw5_expl_q4_awac_medium_supervised_lam2_PointmassMedium-v0_08-03-2023_11-09-30
# ../../data/awac/hw5_expl_q4_awac_medium_supervised_lam2_PointmassMedium-v0_09-03-2023_02-06-45
# ../../data/awac/hw5_expl_q4_awac_medium_supervised_lam2_PointmassMedium-v0_09-03-2023_02-11-14

# %% [markdown]
# ## Training Return Plot

# %%
a_lam0_1 = u.average_metrics(lam0_1, 1)
a_lam1 = u.average_metrics(lam1, 1)
a_lam2 = u.average_metrics(lam2, 1)
a_lam10 = u.average_metrics(lam10, 1)
a_lam20 = u.average_metrics(lam20, 1)
a_lam50 = u.average_metrics(lam50, 1)

a_lam0_1[0] = None
a_lam1[0] = None
a_lam2[0] = None
a_lam10[0] = None
a_lam20[0] = None
a_lam50[0] = None

u.plot_arrays("Training Return",[a_lam0_1, a_lam1, a_lam2, a_lam10, a_lam20, a_lam50],
              ['lambda 0.1','lamda 1', 'lamda 2', 'lamda 10', 'lamda 20', 'lamda 50'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
a_lam0_1 = u.average_metrics(lam0_1, 2)
a_lam1 = u.average_metrics(lam1, 2)
a_lam2 = u.average_metrics(lam2, 2)
a_lam10 = u.average_metrics(lam10, 2)
a_lam20 = u.average_metrics(lam20, 2)
a_lam50 = u.average_metrics(lam50, 2)


u.plot_arrays("Evaluation Return",[a_lam0_1, a_lam1, a_lam2, a_lam10, a_lam20, a_lam50],
              ['lambda 0.1','lamda 1', 'lamda 2', 'lamda 10', 'lamda 20', 'lamda 50'])

# %% [markdown]
# ## Comparison Study

# %%
a_lam10 = u.average_metrics(lam10, 2)

a_dqn_20k = u.average_metrics(dqn_20k, 2)
a_cql_20k = u.average_metrics(cql_20k, 2)



u.plot_arrays("Evaluation Return",[a_lam10, a_dqn_20k, a_cql_20k],
              ['AWAC - lamda 10','DQN','CQL-Online'])
