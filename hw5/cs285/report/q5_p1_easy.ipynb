# %% [markdown]
# # Question-5 Part-1 - Pointmass-Easy - Unsupervised

# %%
import utils as u
import numpy as np

# %%
tau0_5 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau05_PointmassEasy-v0_"
tau0_6 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau06_PointmassEasy-v0_"
tau0_7 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau07_PointmassEasy-v0_"
tau0_8 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau08_PointmassEasy-v0_"
tau0_9 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau09_PointmassEasy-v0_"
tau0_95 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau095_PointmassEasy-v0_"
tau0_99 = "../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau099_PointmassEasy-v0_"

# %%
u.print_seeds(tau0_99)
# Out:
# ../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau099_PointmassEasy-v0_12-03-2023_14-48-55
# ../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau099_PointmassEasy-v0_12-03-2023_14-48-57
# ../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau099_PointmassEasy-v0_12-03-2023_19-02-07
# ../../data/iql/hw5_expl_q5_easy_unsupervised_lam20_tau099_PointmassEasy-v0_12-03-2023_19-04-50

# %% [markdown]
# ## Training Return Plot

# %%
a_tau0_5 = u.average_metrics(tau0_5, 1)
a_tau0_6 = u.average_metrics(tau0_6, 1)
a_tau0_7 = u.average_metrics(tau0_7, 1)
a_tau0_8 = u.average_metrics(tau0_8, 1)
a_tau0_9 = u.average_metrics(tau0_9, 1)
a_tau0_95 = u.average_metrics(tau0_95, 1)
a_tau0_99 = u.average_metrics(tau0_99, 1)

a_tau0_5[0] = None
a_tau0_6[0] = None
a_tau0_7[0] = None
a_tau0_8[0] = None
a_tau0_9[0] = None
a_tau0_95[0] = None
a_tau0_99[0] = None

u.plot_arrays("Training Return",[a_tau0_5, a_tau0_6, a_tau0_7, a_tau0_8, a_tau0_9, a_tau0_95, a_tau0_99],
              ['tau 0.5','tau 0.6', 'tau 0.7', 'tau 0.8', 'tau 0.9', 'tau 0.95','tau 0.99'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
a_tau0_5 = u.average_metrics(tau0_5, 2)
a_tau0_6 = u.average_metrics(tau0_6, 2)
a_tau0_7 = u.average_metrics(tau0_7, 2)
a_tau0_8 = u.average_metrics(tau0_8, 2)
a_tau0_9 = u.average_metrics(tau0_9, 2)
a_tau0_95 = u.average_metrics(tau0_95,2)
a_tau0_99 = u.average_metrics(tau0_99, 2)

u.plot_arrays("Evaluation Return",[a_tau0_5, a_tau0_6, a_tau0_7, a_tau0_8, a_tau0_9, a_tau0_95, a_tau0_99],
              ['tau 0.5','tau 0.6', 'tau 0.7', 'tau 0.8', 'tau 0.9', 'tau 0.95','tau 0.99'])
