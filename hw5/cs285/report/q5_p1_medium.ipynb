# %% [markdown]
# # Question-5 Part-1 - Pointmass-Medium - Unsupervised

# %%
import utils as u
import numpy as np

# %%
tau0_5 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau05_PointmassMedium-v0_"
tau0_6 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau06_PointmassMedium-v0_"
tau0_7 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau07_PointmassMedium-v0_"
tau0_8 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau08_PointmassMedium-v0_"
tau0_9 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau09_PointmassMedium-v0_"
tau0_95 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau095_PointmassMedium-v0_"
tau0_99 = "../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau099_PointmassMedium-v0_"

lam20 = "../../data/awac/hw5_expl_q4_awac_medium_unsupervised_lam20_"
cql_a0_02_shifted = "../../data/p2-p3/hw5_expl_q2_alpha0_02_PointmassMedium-v0_*"
dqn_online_shifted = "../../data/q2-p1/hw5_expl_q1_env2_rnd_shifted_PointmassMedium-v0_*"
dqn_off_20000_shifted = "../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_*"

# %%
u.print_seeds(tau0_8)
# Out:
# ../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau08_PointmassMedium-v0_13-03-2023_11-47-34
# ../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau08_PointmassMedium-v0_13-03-2023_11-48-55
# ../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau08_PointmassMedium-v0_13-03-2023_18-09-52
# ../../data/iql/hw5_expl_q5_medium_unsupervised_lam20_tau08_PointmassMedium-v0_13-03-2023_18-11-19

# %% [markdown]
# ## Training Return Plot

# %%
a_tau0_5 = u.average_metrics(tau0_5, 1)
a_tau0_6 = u.average_metrics(tau0_6, 1)
a_tau0_7 = u.average_metrics(tau0_7, 1)
a_tau0_8 = u.average_metrics(tau0_8, 1)
a_tau0_9 = u.average_metrics(tau0_9, 1)
a_tau0_95 = u.average_metrics(tau0_95, 1)
a_tau0_99 = u.average_metrics(tau0_99, 1)

a_tau0_5[0] = None
a_tau0_6[0] = None
a_tau0_7[0] = None
a_tau0_8[0] = None
a_tau0_9[0] = None
a_tau0_95[0] = None
a_tau0_99[0] = None

u.plot_arrays("Training Return",[a_tau0_5, a_tau0_6, a_tau0_7, a_tau0_8, a_tau0_9, a_tau0_95, a_tau0_99],
              ['tau 0.5','tau 0.6', 'tau 0.7', 'tau 0.8', 'tau 0.9', 'tau 0.95','tau 0.99'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
a_tau0_5 = u.average_metrics(tau0_5, 2)
a_tau0_6 = u.average_metrics(tau0_6, 2)
a_tau0_7 = u.average_metrics(tau0_7, 2)
a_tau0_8 = u.average_metrics(tau0_8, 2)
a_tau0_9 = u.average_metrics(tau0_9, 2)
a_tau0_95 = u.average_metrics(tau0_95,2)
a_tau0_99 = u.average_metrics(tau0_99, 2)

u.plot_arrays("Evaluation Return",[a_tau0_5, a_tau0_6, a_tau0_7, a_tau0_8, a_tau0_9, a_tau0_95, a_tau0_99],
              ['tau 0.5','tau 0.6', 'tau 0.7', 'tau 0.8', 'tau 0.9', 'tau 0.95','tau 0.99'])

# %% [markdown]
# ## Comparing to other algorithms

# %%
a_lam20 = u.average_metrics(lam20, 2)
a_cql_a0_02_shifted = u.average_metrics(cql_a0_02_shifted, 2)
a_dqn_online_shifted = u.average_metrics(dqn_online_shifted, 2)
a_dqn_off_20000_shifted = u.average_metrics(dqn_off_20000_shifted, 2)
a_tau0_95 = u.average_metrics(tau0_95,2)

u.plot_arrays("Evaluation Return",[a_lam20, a_cql_a0_02_shifted, a_dqn_online_shifted, a_dqn_off_20000_shifted, a_tau0_95],
              ['AWAC - lamda 20 - expl20K','CQL Offline - alpha 0.02 - expl20K','DQN - expl10K','DQN Offline - expl20K', 'IQL Lambda 20 tau 0.95'])
