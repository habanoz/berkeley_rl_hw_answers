# %% [markdown]
# # Question-5 Part-2 - Pointmass-Medium - Supervised

# %%
import utils as u
import numpy as np

# %%
tau0_5 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau05_PointmassMedium-v0_"
tau0_6 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau06_PointmassMedium-v0_"
tau0_7 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau07_PointmassMedium-v0_"
tau0_8 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau08_PointmassMedium-v0_"
tau0_9 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau09_PointmassMedium-v0_"
tau0_95 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau095_PointmassMedium-v0_"
tau0_99 = "../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau099_PointmassMedium-v0_"

lam10 = "../../data/awac/hw5_expl_q4_awac_medium_supervised_lam10_"
dqn_online_shifted = "../../data/q2-p1/hw5_expl_q1_env2_rnd_shifted_PointmassMedium-v0_*"
dqn_off_20000_shifted = "../../data/p2-p2/hw5_expl_q2_dqn_numsteps_20000_PointmassMedium-v0_*"
dqn_20k = "../../data/p3/hw5_expl_q3_medium_dqn_PointmassMedium-v0_*"
cql_20k = "../../data/p3/hw5_expl_q3_medium_cql_PointmassMedium-v0_*"

# %%
u.print_seeds(tau0_5)
# Out:
# ../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau05_PointmassMedium-v0_12-03-2023_19-56-21
# ../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau05_PointmassMedium-v0_12-03-2023_19-56-25
# ../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau05_PointmassMedium-v0_13-03-2023_00-33-55
# ../../data/iql/hw5_expl_q5_medium_supervised_lam10_tau05_PointmassMedium-v0_13-03-2023_00-38-55

# %% [markdown]
# ## Training Return Plot

# %%
a_tau0_5 = u.average_metrics(tau0_5, 1)
a_tau0_6 = u.average_metrics(tau0_6, 1)
a_tau0_7 = u.average_metrics(tau0_7, 1)
a_tau0_8 = u.average_metrics(tau0_8, 1)
a_tau0_9 = u.average_metrics(tau0_9, 1)
a_tau0_95 = u.average_metrics(tau0_95, 1)
a_tau0_99 = u.average_metrics(tau0_99, 1)

a_tau0_5[0] = None
a_tau0_6[0] = None
a_tau0_7[0] = None
a_tau0_8[0] = None
a_tau0_9[0] = None
a_tau0_95[0] = None
a_tau0_99[0] = None

u.plot_arrays("Training Return",[a_tau0_5, a_tau0_6, a_tau0_7, a_tau0_8, a_tau0_9, a_tau0_95, a_tau0_99],
              ['tau 0.5','tau 0.6', 'tau 0.7', 'tau 0.8', 'tau 0.9', 'tau 0.95','tau 0.99'])

# %% [markdown]
# ## Evaluation Return Plot

# %%
a_tau0_5 = u.average_metrics(tau0_5, 2)
a_tau0_6 = u.average_metrics(tau0_6, 2)
a_tau0_7 = u.average_metrics(tau0_7, 2)
a_tau0_8 = u.average_metrics(tau0_8, 2)
a_tau0_9 = u.average_metrics(tau0_9, 2)
a_tau0_95 = u.average_metrics(tau0_95,2)
a_tau0_99 = u.average_metrics(tau0_99, 2)

u.plot_arrays("Evaluation Return",[a_tau0_5, a_tau0_6, a_tau0_7, a_tau0_8, a_tau0_9, a_tau0_95, a_tau0_99],
              ['tau 0.5','tau 0.6', 'tau 0.7', 'tau 0.8', 'tau 0.9', 'tau 0.95','tau 0.99'])

# %% [markdown]
# ## Compared to other algorithms

# %%
a_lam10 = u.average_metrics(lam10, 2)
a_dqn_20k = u.average_metrics(dqn_20k, 2)
a_cql_20k = u.average_metrics(cql_20k, 2)

a_tau0_9 = u.average_metrics(tau0_9, 2)


u.plot_arrays("Evaluation Return",[a_lam10, a_dqn_20k, a_cql_20k, a_tau0_9],
              ['AWAC - lamda 10','DQN','CQL-Online', 'IQL - lamda 10 - tau 0.9'])
